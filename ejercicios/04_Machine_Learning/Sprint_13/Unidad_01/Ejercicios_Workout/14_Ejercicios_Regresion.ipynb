# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Para ejercitarte y afianzar lo aprendido sobre **Regresion con Árboles de decisión**, completa los siguientes ejercicios. Recuerda que necesitarás datos que están en el directorio data que acompaña al notebook (búscalo en el repositorio de ejercicios)
#
# La solución a los mismos las tienes ya, intenta no mirarlos de primeras pero no dejes de hacerlo cuando hayas terminado por si te pudieran aportar.

# %% [markdown]
# Este conjunto de ejercicios trabajan sobre un dataset de temperaturas tomados de la ciudad de Seattle. El objetivo es intentar predecir lo mejor posible la máxima temperatura (columna `actual`) que alcanzaremos al día siguiente. Para ello contaremos con temperaturas de los dos días anteriores, históricos de máximas temperaturas y un amigo bastante chapas que te da su predicción del tiempo cada día.
#
# **Resumen de datos**:
# * year: 2016 for all data points
# * month: number for month of the year
# * day: number for day of the year
# * week: day of the week as a character string
# * temp_2: max temperature 2 days prior
# * temp_1: max temperature 1 day prior
# * average: historical average max temperature
# * actual: max temperature measurement
# * friend: your friend’s prediction, a random number between 20 below the average and 20 above the average

# %% [markdown]
# ### Ejercicio 0
#
# Importa los paquetes y módulos que necesites a lo largo del notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn

from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Ejercicio 1
#
# Importa el csv "temps.csv"

# %%
df = pd.read_csv("./data/temps.csv")
df
# Out:
#      year  month  day   week  temp_2  temp_1  average  actual  forecast_noaa  \
# 0    2016      1    1    Fri      45      45     45.6      45             43
# 1    2016      1    2    Sat      44      45     45.7      44             41
# 2    2016      1    3    Sun      45      44     45.8      41             43
# 3    2016      1    4    Mon      44      41     45.9      40             44
# 4    2016      1    5   Tues      41      40     46.0      44             46
# ..    ...    ...  ...    ...     ...     ...      ...     ...            ...
# 343  2016     12   27   Tues      42      42     45.2      47             41
# 344  2016     12   28    Wed      42      47     45.3      48             41
# 345  2016     12   29  Thurs      47      48     45.3      48             43
# 346  2016     12   30    Fri      48      48     45.4      57             44
# 347  2016     12   31    Sat      48      57     45.5      40             42
#
#      forecast_acc  forecast_under  friend
# 0              50              44      29
# 1              50              44      61
# 2              46              47      56
# 3              48              46      53
# 4              46              46      41
# ..            ...             ...     ...
# 343            50              47      47
# 344            49              44      58
# 345            50              45      65
# 346            46              44      42
# 347            48              47      57
#
# [348 rows x 12 columns]

# %%
df.drop(columns=["year"], inplace=True)

# %% [markdown]
# ### Ejercicio 2
#
# Haz un one-hot encoding de las variables categóricas del dataset

# %%
df = pd.get_dummies(df)
df.sample(20)
# Out:
#      month  day  temp_2  temp_1  average  actual  forecast_noaa  forecast_acc  \
# 147      5   30      64      64     67.1      71             64            70
# 52       2   24      51      60     50.8      59             47            53
# 182      7    4      76      71     73.8      68             71            76
# 277     10   21      58      62     57.8      59             56            60
# 102      4   15      59      59     58.3      60             58            61
# 275     10   19      60      61     58.4      58             58            60
# 79       3   23      56      57     54.7      53             50            58
# 303     11   17      55      50     50.5      52             46            51
# 83       3   27      57      59     55.3      51             52            58
# 235      9    9      67      72     72.6      74             68            77
# 245      9   19      68      69     69.7      71             65            74
# 194      7   16      77      76     76.1      72             76            78
# 332     12   16      39      39     45.3      35             44            49
# 125      5    8      77      82     63.2      63             62            65
# 264     10    8      63      64     62.5      68             60            65
# 93       4    6      60      57     56.8      68             53            59
# 200      7   22      82      81     76.9      71             72            77
# 269     10   13      62      66     60.6      60             60            62
# 314     11   28      53      48     48.0      52             46            48
# 239      9   13      70      74     71.5      75             71            75
#
#      forecast_under  friend  week_Fri  week_Mon  week_Sat  week_Sun  \
# 147              66      69     False      True     False     False
# 52               50      46     False     False     False     False
# 182              73      86     False      True     False     False
# 277              59      44      True     False     False     False
# 102              60      40      True     False     False     False
# 275              57      41     False     False     False     False
# 79               55      70     False     False     False     False
# 303              50      57     False     False     False     False
# 83               55      39     False     False     False      True
# 235              71      78      True     False     False     False
# 245              71      88     False      True     False     False
# 194              75      61     False     False      True     False
# 332              44      39      True     False     False     False
# 125              63      83     False     False     False      True
# 264              61      73     False     False      True     False
# 93               57      64     False     False     False     False
# 200              76      70      True     False     False     False
# 269              60      57     False     False     False     False
# 314              49      44     False      True     False     False
# 239              70      82     False     False     False     False
#
#      week_Thurs  week_Tues  week_Wed
# 147       False      False     False
# 52        False      False      True
# 182       False      False     False
# 277       False      False     False
# 102       False      False     False
# 275       False      False      True
# 79        False      False      True
# 303        True      False     False
# 83        False      False     False
# 235       False      False     False
# 245       False      False     False
# 194       False      False     False
# 332       False      False     False
# 125       False      False     False
# 264       False      False     False
# 93        False      False      True
# 200       False      False     False
# 269        True      False     False
# 314       False      False     False
# 239       False       True     False

# %% [markdown]
# ### Ejercicio 3
#
# Divide en train y test

# %%
X = df.drop(columns=["actual"])
y = df["actual"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)

# %% [markdown]
# ### Ejercicio 4
#
# Instancia un DecisionTreeRegressor de sklearn con hiperparámetros por defecto y entrénalo.

# %%
from sklearn.tree import DecisionTreeRegressor
tree = DecisionTreeRegressor()
tree.fit(X_train, y_train)
pred = tree.predict(X_test)

# %% [markdown]
# ### Ejercicio 5
#
# Calcula su MAE sin usar sklearn.

# %%
error = abs(y_test - pred)
error.mean()
# Out:
# 4.742857142857143

# %% [markdown]
# ### Ejercicio 6
#
# Calcula su MAPE sin usar sklearn

# %%
(error/y_test).mean() * 100
# Out:
# 7.505404147471789

# %% [markdown]
# ### Ejercicio 7
#
# Representa el árbol de decision

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(10, 6))
plot_tree(tree, filled=True, feature_names=X.columns)
plt.show()

# %% [markdown]
# ### Ejercicio 8.
#
# Instancia un nuevo árbol ahora con max_depth a 3 y vuelve a entrenarlo

# %%
tree3 = DecisionTreeRegressor(max_depth=3)
tree3.fit(X_train, y_train)
pred3 = tree3.predict(X_test)

# %% [markdown]
# ### Ejercicio 9
#
# Vuelve a calcular MAE y MAPE

# %%
# mae
error = abs(y_test - pred3)
print("MAE", error.mean())

print("MAPE", (error/y_test).mean() * 100)
# Out:
# MAE 4.5567196265742504
# MAPE 7.147155657048517

# %% [markdown]
# ### Ejercicio 10
#
# Vuelve a representar su árbol

# %%
plt.figure(figsize=(10, 6))
plot_tree(tree3, filled=True, feature_names=X.columns)
plt.show()

# %% [markdown]
# ### Ejercicio 11
#
# Obten el `feature_importances` de cada variable en el último modelo. Los árboles una vez entrenados tienen un atributo que te lo permite, revisa la documentación si es necesario.

# %%
tree3.feature_importances_
# Out:
# array([0.        , 0.        , 0.        , 0.88020751, 0.08841159,
#        0.        , 0.01060993, 0.02077097, 0.        , 0.        ,
#        0.        , 0.        , 0.        , 0.        , 0.        ,
#        0.        ])

# %%
pd.DataFrame({'features':X.columns,
              'importance':tree3.feature_importances_})
# Out:
#           features  importance
# 0            month    0.000000
# 1              day    0.000000
# 2           temp_2    0.000000
# 3           temp_1    0.880208
# 4          average    0.088412
# 5    forecast_noaa    0.000000
# 6     forecast_acc    0.010610
# 7   forecast_under    0.020771
# 8           friend    0.000000
# 9         week_Fri    0.000000
# 10        week_Mon    0.000000
# 11        week_Sat    0.000000
# 12        week_Sun    0.000000
# 13      week_Thurs    0.000000
# 14       week_Tues    0.000000
# 15        week_Wed    0.000000
