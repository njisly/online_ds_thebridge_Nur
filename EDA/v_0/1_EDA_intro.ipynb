# %% [markdown]
# # The Academy Awards, 1927 - 2023
#
# Este [dataset](https://www.kaggle.com/datasets/unanimad/the-oscar-award) contiene un scraping de la base de datos de los Premios de la Academia, registros de los nominados y ganadores desde 1927 hasta 2023.

# %% [markdown]
# En este EDA cruzaré los datos de diferentes datasets de las películas con las nominadas y ganadoras a mejor pelicula para ver si los miembros de la academia siguen algun tipo de patron o *bias* para elegir la ganadora.

# %%
import pandas as pd

# %%
df_oscars = pd.read_csv("./data/the_oscar_award.csv")
df_oscars
# Out:
#        year_film  year_ceremony  ceremony                category  \
# 0           1927           1928         1                   ACTOR
# 1           1927           1928         1                   ACTOR
# 2           1927           1928         1                 ACTRESS
# 3           1927           1928         1                 ACTRESS
# 4           1927           1928         1                 ACTRESS
# ...          ...            ...       ...                     ...
# 10760       2022           2023        95          HONORARY AWARD
# 10761       2022           2023        95          HONORARY AWARD
# 10762       2022           2023        95          HONORARY AWARD
# 10763       2022           2023        95  GORDON E. SAWYER AWARD
# 10764       2022           2023        95   AWARD OF COMMENDATION
#
#                                                     name                 film  \
# 0                                    Richard Barthelmess            The Noose
# 1                                          Emil Jannings     The Last Command
# 2                                         Louise Dresser      A Ship Comes In
# 3                                           Janet Gaynor           7th Heaven
# 4                                         Gloria Swanson       Sadie Thompson
# ...                                                  ...                  ...
# 10760  To Euzhan Palcy, a masterful filmmaker who bro...                  NaN
# 10761  To Diane Warren, for her genius, generosity an...                  NaN
# 10762  To Peter Weir, a fearless and consummate filmm...                  NaN
# 10763                                          Iain Neil                  NaN
# 10764  To Ryan Laney for his innovative adaptation an...  Welcome to Chechnya
#
#        winner
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
# ...       ...
# 10760    True
# 10761    True
# 10762    True
# 10763    True
# 10764    True
#
# [10765 rows x 7 columns]

# %% [markdown]
# ### Los diferentes nombres que ha tenido la categoria para mejor película a lo largo de los años
# 1927/28–1928/29: Academy Award for Outstanding Picture
# 1929/30–1940: Academy Award for Outstanding Production
# 1941–1943: Academy Award for Outstanding Motion Picture
# 1944–1961: Academy Award for Best Motion Picture
# 1962–present: Academy Award for Best Picture

# %%
BEST_PICTURE = df_oscars.category == "BEST PICTURE"
OUTSTANDING_PICTURE =  df_oscars.category == "OUTSTANDING PICTURE"
OUTSTANDING_PRODUCTION = df_oscars.category == "OUTSTANDING PRODUCTION"
OUSTANDING_MOTION_PICTURE = df_oscars.category == "OUTSTANDING MOTION PICTURE"
BEST_MOTION_PICTURE = df_oscars.category == "BEST MOTION PICTURE"

df_best_picture = df_oscars[BEST_PICTURE | OUTSTANDING_PICTURE | OUTSTANDING_PRODUCTION | OUSTANDING_MOTION_PICTURE | BEST_MOTION_PICTURE]
df_best_picture
# Out:
#        year_film  year_ceremony  ceremony             category  \
# 19          1927           1928         1  OUTSTANDING PICTURE
# 20          1927           1928         1  OUTSTANDING PICTURE
# 21          1927           1928         1  OUTSTANDING PICTURE
# 62          1928           1929         2  OUTSTANDING PICTURE
# 63          1928           1929         2  OUTSTANDING PICTURE
# ...          ...            ...       ...                  ...
# 10719       2022           2023        95         BEST PICTURE
# 10720       2022           2023        95         BEST PICTURE
# 10721       2022           2023        95         BEST PICTURE
# 10722       2022           2023        95         BEST PICTURE
# 10723       2022           2023        95         BEST PICTURE
#
#                                                     name                 film  \
# 19                                     The Caddo Company           The Racket
# 20                                                   Fox           7th Heaven
# 21                                Paramount Famous Lasky                Wings
# 62                                   Feature Productions                Alibi
# 63                                                   Fox       In Old Arizona
# ...                                                  ...                  ...
# 10719  Kristie Macosko Krieger, Steven Spielberg and ...        The Fabelmans
# 10720  Todd Field, Alexandra Milchan and Scott Lamber...                  Tár
# 10721  Tom Cruise, Christopher McQuarrie, David Ellis...    Top Gun: Maverick
# 10722     Erik Hemmendorff and Philippe Bober, Producers  Triangle of Sadness
# 10723  Dede Gardner, Jeremy Kleiner and Frances McDor...        Women Talking
#
#        winner
# 19      False
# 20      False
# 21       True
# 62      False
# 63      False
# ...       ...
# 10719   False
# 10720   False
# 10721   False
# 10722   False
# 10723   False
#
# [591 rows x 7 columns]

# %%
df_best_picture[df_best_picture.winner]
# para asegurarme de que tengo 95 años de datos
# Out:
#        year_film  year_ceremony  ceremony                category  \
# 21          1927           1928         1     OUTSTANDING PICTURE
# 64          1928           1929         2     OUTSTANDING PICTURE
# 100         1929           1930         3  OUTSTANDING PRODUCTION
# 140         1930           1931         4  OUTSTANDING PRODUCTION
# 178         1931           1932         5  OUTSTANDING PRODUCTION
# ...          ...            ...       ...                     ...
# 10219       2018           2019        91            BEST PICTURE
# 10350       2019           2020        92            BEST PICTURE
# 10474       2020           2021        93            BEST PICTURE
# 10591       2021           2022        94            BEST PICTURE
# 10718       2022           2023        95            BEST PICTURE
#
#                                                     name  \
# 21                                Paramount Famous Lasky
# 64                                   Metro-Goldwyn-Mayer
# 100                                            Universal
# 140                                            RKO Radio
# 178                                  Metro-Goldwyn-Mayer
# ...                                                  ...
# 10219  Jim Burke, Charles B. Wessler, Brian Currie, P...
# 10350            Kwak Sin Ae and Bong Joon Ho, Producers
# 10474  Frances McDormand, Peter Spears, Mollye Asher,...
# 10591  Philippe Rousselet, Fabrice Gianfermi and Patr...
# 10718  Daniel Kwan, Daniel Scheinert and Jonathan Wan...
#
#                                     film  winner
# 21                                 Wings    True
# 64                   The Broadway Melody    True
# 100       All Quiet on the Western Front    True
# 140                             Cimarron    True
# 178                          Grand Hotel    True
# ...                                  ...     ...
# 10219                         Green Book    True
# 10350                           Parasite    True
# 10474                          Nomadland    True
# 10591                               CODA    True
# 10718  Everything Everywhere All at Once    True
#
# [95 rows x 7 columns]

# %%
df_best_picture.drop(columns="category", inplace=True) # no la necesito
df_best_picture.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 591 entries, 19 to 10723
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year_film      591 non-null    int64
#  1   year_ceremony  591 non-null    int64
#  2   ceremony       591 non-null    int64
#  3   name           591 non-null    object
#  4   film           591 non-null    object
#  5   winner         591 non-null    bool
# dtypes: bool(1), int64(3), object(2)
# memory usage: 28.3+ KB
# C:\Users\Nur\AppData\Local\Temp\ipykernel_5936\4077061513.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_best_picture.drop(columns="category", inplace=True) # no la necesito

# %% [markdown]
# |columna|descripcion|
# |-|-|
# |year_film|Año de estreno|
# |year_ceremony| Año en que se celebró la gala|
# |ceremony|Número de ceremonia|
# |name|Nombre de la productora/los productores|
# |film|Título de la película|
# |winner|Bool True si ganó|

# %%
df_best_picture.sample(50)
# Out:
#       year_film  year_ceremony  ceremony  \
# 605        1937           1938        10
# 379        1935           1936         8
# 2029       1946           1947        19
# 7746       1997           1998        70
# 3326       1957           1958        30
# 8755       2006           2007        79
# 6112       1982           1983        55
# 5695       1978           1979        51
# 484        1936           1937         9
# 1206       1941           1942        14
# 6859       1989           1990        62
# 9718       2014           2015        87
# 6753       1988           1989        61
# 5482       1976           1977        49
# 3561       1959           1960        32
# 1027       1940           1941        13
# 7515       1995           1996        68
# 3681       1960           1961        33
# 4957       1971           1972        44
# 6331       1984           1985        57
# 878        1939           1940        12
# 380        1935           1936         8
# 9967       2016           2017        89
# 7747       1997           1998        70
# 304        1934           1935         7
# 4746       1969           1970        42
# 1028       1940           1941        13
# 5481       1976           1977        49
# 9587       2013           2014        86
# 4418       1966           1967        39
# 6116       1982           1983        55
# 6009       1981           1982        54
# 9842       2015           2016        88
# 2133       1947           1948        20
# 175        1931           1932         5
# 140        1930           1931         4
# 3444       1958           1959        31
# 3924       1962           1963        35
# 9965       2016           2017        89
# 3223       1956           1957        29
# 9589       2013           2014        86
# 2711       1952           1953        25
# 3802       1961           1962        34
# 729        1938           1939        11
# 5584       1977           1978        50
# 2471       1950           1951        23
# 877        1939           1940        12
# 4174       1964           1965        37
# 7291       1993           1994        66
# 488        1936           1937         9
#
#                                                    name  \
# 605                                           Universal
# 379                                 Metro-Goldwyn-Mayer
# 2029                                      Liberty Films
# 7746  James L. Brooks, Bridget Johnson and Kristi Ze...
# 3326                               Jerry Wald, Producer
# 8755  Andy Harries, Christine Langan and Tracey Seaw...
# 6112   Steven Spielberg and Kathleen Kennedy, Producers
# 5695              Paul Mazursky and Tony Ray, Producers
# 484                                 Metro-Goldwyn-Mayer
# 1206                                       Warner Bros.
# 6859                             Noel Pearson, Producer
# 9718  Christian Colson, Oprah Winfrey, Dede Gardner ...
# 6753                             Douglas Wick, Producer
# 5482     Michael Phillips and Julia Phillips, Producers
# 3561                             Henry Blanke, Producer
# 1027                                   20th Century-Fox
# 7515                             Brian Grazer, Producer
# 3681                            Bernard Smith, Producer
# 4957                          Philip D'Antoni, Producer
# 6331                           Arlene Donovan, Producer
# 878                      Hal Roach (production company)
# 380                                           RKO Radio
# 9967  Fred Berger, Jordan Horowitz and Marc Platt, P...
# 7747                          Uberto Pasolini, Producer
# 304                                 Metro-Goldwyn-Mayer
# 4746                           Jerome Hellman, Producer
# 1028                        Charles Chaplin Productions
# 5481       Irwin Winkler and Robert Chartoff, Producers
# 9587  Charles Roven, Richard Suckle, Megan Ellison a...
# 4418                           Fred Zinnemann, Producer
# 6116       Richard D. Zanuck and David Brown, Producers
# 6009                            Warren Beatty, Producer
# 9842  Simon Kinberg, Ridley Scott, Michael Schaefer ...
# 2133                                          RKO Radio
# 175                                                 Fox
# 140                                           RKO Radio
# 3444                             Arthur Freed, Producer
# 3924                         Darryl F. Zanuck, Producer
# 9965             Carla Hacken and Julie Yorn, Producers
# 3223                            William Wyler, Producer
# 9589        Robbie Brenner and Rachel Winter, Producers
# 2711                         Pandro S. Berman, Producer
# 3802                             Carl Foreman, Producer
# 729                         Warner Bros.-First National
# 5584                             Richard Roth, Producer
# 2471                                Metro-Goldwyn-Mayer
# 877                                 Metro-Goldwyn-Mayer
# 4174                       Michael Cacoyannis, Producer
# 7291  Steven Spielberg, Gerald R. Molen and Branko L...
# 488                                           Universal
#
#                               film  winner
# 605     One Hundred Men and a Girl   False
# 379              David Copperfield   False
# 2029         It's a Wonderful Life   False
# 7746            As Good as It Gets   False
# 3326                  Peyton Place   False
# 8755                     The Queen   False
# 6112    E.T. The Extra-Terrestrial   False
# 5695            An Unmarried Woman   False
# 484               Romeo and Juliet   False
# 1206                 Sergeant York   False
# 6859                  My Left Foot   False
# 9718                         Selma   False
# 6753                  Working Girl   False
# 5482                   Taxi Driver   False
# 3561               The Nun's Story   False
# 1027           The Grapes of Wrath   False
# 7515                     Apollo 13   False
# 3681                  Elmer Gantry   False
# 4957         The French Connection    True
# 6331           Places in the Heart   False
# 878                Of Mice and Men   False
# 380                   The Informer   False
# 9967                    La La Land   False
# 7747                The Full Monty   False
# 304                    Viva Villa!   False
# 4746               Midnight Cowboy    True
# 1028            The Great Dictator   False
# 5481                         Rocky    True
# 9587               American Hustle   False
# 4418         A Man for All Seasons    True
# 6116                   The Verdict   False
# 6009                          Reds   False
# 9842                   The Martian   False
# 2133                     Crossfire   False
# 175                       Bad Girl   False
# 140                       Cimarron    True
# 3444                          Gigi    True
# 3924               The Longest Day   False
# 9965            Hell or High Water   False
# 3223           Friendly Persuasion   False
# 9589            Dallas Buyers Club   False
# 2711                       Ivanhoe   False
# 3802          The Guns of Navarone   False
# 729   The Adventures of Robin Hood   False
# 5584                         Julia   False
# 2471           Father of the Bride   False
# 877                      Ninotchka   False
# 4174               Zorba the Greek   False
# 7291              Schindler's List    True
# 488              Three Smart Girls   False

# %%
df_best_picture.to_csv("./data/best_picture.csv", index=False)
